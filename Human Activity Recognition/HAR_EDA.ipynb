# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, encoding='latin-1')
X_train.columns = features

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1285           0.143609           0.002423          -0.119384
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1285           0.19969          0.422328         -0.223397          0.129353
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1285          0.366185          -0.22193          0.401342  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1285                      0.89024                             -0.945232
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1285                           0.75966                              0.679176
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1285             -0.777405              0.251605              0.028866
#
#       subject  Activity        ActivityName
# 1285        6         3  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, encoding='latin-1')
X_test.columns = features

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 589           0.261702           0.009812          -0.131337
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 589          0.190528          0.000131         -0.430028          0.111218
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 589         -0.069914         -0.457054          0.353735  ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 589                     0.177127                              0.352932
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 589                          0.932452                             -0.046956
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 589             -0.874789              0.101783             -0.073953
#
#      subject  Activity        ActivityName
# 589        4         3  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  angle(tBodyAccMean,gravity)  \
# 0         -0.923527         -0.934724  ...                    -0.112754
# 1         -0.957686         -0.943068  ...                     0.053477
# 2         -0.977469         -0.938692  ...                    -0.118559
# 3         -0.989302         -0.938692  ...                    -0.036788
# 4         -0.990441         -0.942469  ...                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity  ActivityName
# 0              0.179941             -0.058627        1         5      STANDING
# 1              0.180289             -0.054317        1         5      STANDING
# 2              0.180637             -0.049118        1         5      STANDING
# 3              0.181935             -0.047663        1         5      STANDING
# 4              0.185151             -0.043892        1         5      STANDING
#
# [5 rows x 564 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=35)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\rajus\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-7b66dca1518a>:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
# <ipython-input-31-7b66dca1518a>:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
# <ipython-input-31-7b66dca1518a>:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
# <ipython-input-31-7b66dca1518a>:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
# <ipython-input-31-7b66dca1518a>:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
# <ipython-input-31-7b66dca1518a>:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.024s...
# [t-SNE] Computed neighbors for 7352 samples in 72.750s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.060s
# [t-SNE] Iteration 50: error = 124.6538696, gradient norm = 0.0320413 (50 iterations in 3.035s)
# [t-SNE] Iteration 100: error = 106.7305298, gradient norm = 0.0291271 (50 iterations in 2.517s)
# [t-SNE] Iteration 150: error = 100.6320724, gradient norm = 0.0193455 (50 iterations in 2.065s)
# [t-SNE] Iteration 200: error = 97.2838287, gradient norm = 0.0169676 (50 iterations in 2.301s)
# [t-SNE] Iteration 250: error = 95.0119858, gradient norm = 0.0144989 (50 iterations in 2.465s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.011986
# [t-SNE] Iteration 300: error = 4.1149735, gradient norm = 0.0015618 (50 iterations in 2.392s)
# [t-SNE] Iteration 350: error = 3.2073073, gradient norm = 0.0009959 (50 iterations in 2.383s)
# [t-SNE] Iteration 400: error = 2.7779188, gradient norm = 0.0007177 (50 iterations in 2.348s)
# [t-SNE] Iteration 450: error = 2.5139470, gradient norm = 0.0005649 (50 iterations in 2.370s)
# [t-SNE] Iteration 500: error = 2.3306742, gradient norm = 0.0004772 (50 iterations in 2.423s)
# [t-SNE] Iteration 550: error = 2.1925900, gradient norm = 0.0004173 (50 iterations in 2.309s)
# [t-SNE] Iteration 600: error = 2.0834718, gradient norm = 0.0003660 (50 iterations in 2.383s)
# [t-SNE] Iteration 650: error = 1.9936116, gradient norm = 0.0003302 (50 iterations in 2.452s)
# [t-SNE] Iteration 700: error = 1.9179479, gradient norm = 0.0003037 (50 iterations in 2.189s)
# [t-SNE] Iteration 750: error = 1.8530358, gradient norm = 0.0002788 (50 iterations in 1.892s)
# [t-SNE] Iteration 800: error = 1.7963624, gradient norm = 0.0002589 (50 iterations in 1.882s)
# [t-SNE] Iteration 850: error = 1.7462916, gradient norm = 0.0002388 (50 iterations in 1.865s)
# [t-SNE] Iteration 900: error = 1.7016653, gradient norm = 0.0002226 (50 iterations in 2.005s)
# [t-SNE] Iteration 950: error = 1.6616485, gradient norm = 0.0002092 (50 iterations in 1.959s)
# [t-SNE] Iteration 1000: error = 1.6251746, gradient norm = 0.0001984 (50 iterations in 2.396s)
# [t-SNE] KL divergence after 1000 iterations: 1.625175
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.873s...
# [t-SNE] Computed neighbors for 7352 samples in 73.891s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.103s
# [t-SNE] Iteration 50: error = 113.9734344, gradient norm = 0.0220025 (50 iterations in 6.341s)
# [t-SNE] Iteration 100: error = 97.4448013, gradient norm = 0.0150994 (50 iterations in 2.885s)
# [t-SNE] Iteration 150: error = 93.1492767, gradient norm = 0.0092806 (50 iterations in 2.661s)
# [t-SNE] Iteration 200: error = 91.1765976, gradient norm = 0.0071997 (50 iterations in 2.486s)
# [t-SNE] Iteration 250: error = 89.9866104, gradient norm = 0.0058849 (50 iterations in 2.506s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.986610
# [t-SNE] Iteration 300: error = 3.5737693, gradient norm = 0.0014665 (50 iterations in 2.427s)
# [t-SNE] Iteration 350: error = 2.8152459, gradient norm = 0.0007480 (50 iterations in 2.464s)
# [t-SNE] Iteration 400: error = 2.4342878, gradient norm = 0.0005256 (50 iterations in 2.368s)
# [t-SNE] Iteration 450: error = 2.2169149, gradient norm = 0.0004124 (50 iterations in 2.481s)
# [t-SNE] Iteration 500: error = 2.0721228, gradient norm = 0.0003343 (50 iterations in 2.461s)
# [t-SNE] Iteration 550: error = 1.9669461, gradient norm = 0.0002850 (50 iterations in 2.659s)
# [t-SNE] Iteration 600: error = 1.8856107, gradient norm = 0.0002474 (50 iterations in 2.470s)
# [t-SNE] Iteration 650: error = 1.8206319, gradient norm = 0.0002215 (50 iterations in 2.661s)
# [t-SNE] Iteration 700: error = 1.7668986, gradient norm = 0.0001982 (50 iterations in 2.631s)
# [t-SNE] Iteration 750: error = 1.7215424, gradient norm = 0.0001811 (50 iterations in 2.492s)
# [t-SNE] Iteration 800: error = 1.6823921, gradient norm = 0.0001667 (50 iterations in 2.730s)
# [t-SNE] Iteration 850: error = 1.6484013, gradient norm = 0.0001538 (50 iterations in 2.665s)
# [t-SNE] Iteration 900: error = 1.6188686, gradient norm = 0.0001426 (50 iterations in 2.646s)
# [t-SNE] Iteration 950: error = 1.5931357, gradient norm = 0.0001331 (50 iterations in 2.718s)
# [t-SNE] Iteration 1000: error = 1.5701487, gradient norm = 0.0001272 (50 iterations in 2.653s)
# [t-SNE] KL divergence after 1000 iterations: 1.570149
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.934s...
# [t-SNE] Computed neighbors for 7352 samples in 74.832s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.189s
# [t-SNE] Iteration 50: error = 105.8884964, gradient norm = 0.0189111 (50 iterations in 3.504s)
# [t-SNE] Iteration 100: error = 90.5206223, gradient norm = 0.0118631 (50 iterations in 2.911s)
# [t-SNE] Iteration 150: error = 87.4110870, gradient norm = 0.0067587 (50 iterations in 2.750s)
# [t-SNE] Iteration 200: error = 86.1203461, gradient norm = 0.0071071 (50 iterations in 2.629s)
# [t-SNE] Iteration 250: error = 85.3828354, gradient norm = 0.0038543 (50 iterations in 2.691s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.382835
# [t-SNE] Iteration 300: error = 3.1315689, gradient norm = 0.0013875 (50 iterations in 2.576s)
# [t-SNE] Iteration 350: error = 2.4903162, gradient norm = 0.0006509 (50 iterations in 2.617s)
# [t-SNE] Iteration 400: error = 2.1710501, gradient norm = 0.0004227 (50 iterations in 2.330s)
# [t-SNE] Iteration 450: error = 1.9866695, gradient norm = 0.0003128 (50 iterations in 2.619s)
# [t-SNE] Iteration 500: error = 1.8686354, gradient norm = 0.0002498 (50 iterations in 2.650s)
# [t-SNE] Iteration 550: error = 1.7853549, gradient norm = 0.0002096 (50 iterations in 2.648s)
# [t-SNE] Iteration 600: error = 1.7228787, gradient norm = 0.0001811 (50 iterations in 2.661s)
# [t-SNE] Iteration 650: error = 1.6738526, gradient norm = 0.0001592 (50 iterations in 2.635s)
# [t-SNE] Iteration 700: error = 1.6343246, gradient norm = 0.0001434 (50 iterations in 2.641s)
# [t-SNE] Iteration 750: error = 1.6014843, gradient norm = 0.0001294 (50 iterations in 2.726s)
# [t-SNE] Iteration 800: error = 1.5737720, gradient norm = 0.0001191 (50 iterations in 2.668s)
# [t-SNE] Iteration 850: error = 1.5501456, gradient norm = 0.0001103 (50 iterations in 2.630s)
# [t-SNE] Iteration 900: error = 1.5298808, gradient norm = 0.0001018 (50 iterations in 2.698s)
# [t-SNE] Iteration 950: error = 1.5119232, gradient norm = 0.0000969 (50 iterations in 2.678s)
# [t-SNE] Iteration 1000: error = 1.4961748, gradient norm = 0.0000912 (50 iterations in 2.617s)
# [t-SNE] KL divergence after 1000 iterations: 1.496175
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.932s...
# [t-SNE] Computed neighbors for 7352 samples in 76.117s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.358s
# [t-SNE] Iteration 50: error = 97.6083069, gradient norm = 0.0174781 (50 iterations in 4.306s)
# [t-SNE] Iteration 100: error = 83.8696671, gradient norm = 0.0066886 (50 iterations in 2.981s)
# [t-SNE] Iteration 150: error = 81.8857269, gradient norm = 0.0032355 (50 iterations in 2.965s)
# [t-SNE] Iteration 200: error = 81.1622696, gradient norm = 0.0025562 (50 iterations in 3.000s)
# [t-SNE] Iteration 250: error = 80.7708969, gradient norm = 0.0032483 (50 iterations in 2.952s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.770897
# [t-SNE] Iteration 300: error = 2.6989305, gradient norm = 0.0013051 (50 iterations in 2.875s)
# [t-SNE] Iteration 350: error = 2.1661298, gradient norm = 0.0005732 (50 iterations in 2.368s)
# [t-SNE] Iteration 400: error = 1.9171416, gradient norm = 0.0003476 (50 iterations in 2.303s)
# [t-SNE] Iteration 450: error = 1.7709837, gradient norm = 0.0002483 (50 iterations in 2.751s)
# [t-SNE] Iteration 500: error = 1.6772726, gradient norm = 0.0001924 (50 iterations in 2.862s)
# [t-SNE] Iteration 550: error = 1.6131643, gradient norm = 0.0001576 (50 iterations in 2.858s)
# [t-SNE] Iteration 600: error = 1.5664833, gradient norm = 0.0001351 (50 iterations in 2.824s)
# [t-SNE] Iteration 650: error = 1.5309619, gradient norm = 0.0001184 (50 iterations in 2.921s)
# [t-SNE] Iteration 700: error = 1.5034677, gradient norm = 0.0001077 (50 iterations in 2.836s)
# [t-SNE] Iteration 750: error = 1.4820216, gradient norm = 0.0000976 (50 iterations in 3.041s)
# [t-SNE] Iteration 800: error = 1.4647398, gradient norm = 0.0000897 (50 iterations in 3.175s)
# [t-SNE] Iteration 850: error = 1.4499625, gradient norm = 0.0000823 (50 iterations in 2.897s)
# [t-SNE] Iteration 900: error = 1.4372133, gradient norm = 0.0000778 (50 iterations in 2.852s)
# [t-SNE] Iteration 950: error = 1.4261410, gradient norm = 0.0000753 (50 iterations in 2.871s)
# [t-SNE] Iteration 1000: error = 1.4172504, gradient norm = 0.0000755 (50 iterations in 2.655s)
# [t-SNE] KL divergence after 1000 iterations: 1.417250
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.904s...
# [t-SNE] Computed neighbors for 7352 samples in 79.355s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 1.011s
# [t-SNE] Iteration 50: error = 85.3756180, gradient norm = 0.0294291 (50 iterations in 3.754s)
# [t-SNE] Iteration 100: error = 75.7361755, gradient norm = 0.0041600 (50 iterations in 3.220s)
# [t-SNE] Iteration 150: error = 74.6746063, gradient norm = 0.0021352 (50 iterations in 3.735s)
# [t-SNE] Iteration 200: error = 74.3060455, gradient norm = 0.0017927 (50 iterations in 3.806s)
# [t-SNE] Iteration 250: error = 74.1258621, gradient norm = 0.0011928 (50 iterations in 3.586s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.125862
# [t-SNE] Iteration 300: error = 2.1596758, gradient norm = 0.0011915 (50 iterations in 3.384s)
# [t-SNE] Iteration 350: error = 1.7609413, gradient norm = 0.0004865 (50 iterations in 2.837s)
# [t-SNE] Iteration 400: error = 1.5918326, gradient norm = 0.0002817 (50 iterations in 2.561s)
# [t-SNE] Iteration 450: error = 1.4977354, gradient norm = 0.0001900 (50 iterations in 2.764s)
# [t-SNE] Iteration 500: error = 1.4375589, gradient norm = 0.0001402 (50 iterations in 2.797s)
# [t-SNE] Iteration 550: error = 1.3961620, gradient norm = 0.0001116 (50 iterations in 2.894s)
# [t-SNE] Iteration 600: error = 1.3666902, gradient norm = 0.0000934 (50 iterations in 3.397s)
# [t-SNE] Iteration 650: error = 1.3453857, gradient norm = 0.0000815 (50 iterations in 3.578s)
# [t-SNE] Iteration 700: error = 1.3296801, gradient norm = 0.0000753 (50 iterations in 3.562s)
# [t-SNE] Iteration 750: error = 1.3181670, gradient norm = 0.0000693 (50 iterations in 3.583s)
# [t-SNE] Iteration 800: error = 1.3093628, gradient norm = 0.0000630 (50 iterations in 3.591s)
# [t-SNE] Iteration 850: error = 1.3020934, gradient norm = 0.0000596 (50 iterations in 3.606s)
# [t-SNE] Iteration 900: error = 1.2960367, gradient norm = 0.0000559 (50 iterations in 3.611s)
# [t-SNE] Iteration 950: error = 1.2909726, gradient norm = 0.0000538 (50 iterations in 3.674s)
# [t-SNE] Iteration 1000: error = 1.2867284, gradient norm = 0.0000511 (50 iterations in 3.314s)
# [t-SNE] KL divergence after 1000 iterations: 1.286728
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
